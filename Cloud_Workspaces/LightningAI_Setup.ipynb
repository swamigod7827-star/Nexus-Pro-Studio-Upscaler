# %% [markdown]
# # 🚀 Nexus Pro Studio - Lightning AI GPU Setup
# Run this notebook to instantly set up your project on Lightning AI Studio without manually uploading heavy files.

# %%
GITHUB_REPO_URL = "https://github.com/swamigod7827-star/Nexus-Pro-Studio-Upscaler.git"
PORT = 5000

# %%
import os
import subprocess

repo_name = GITHUB_REPO_URL.split('/')[-1].replace('.git', '')

# 1. Clone the Repository
# !git clone $GITHUB_REPO_URL

# 2. Change Directory
os.chdir(repo_name)

# 3. Install Dependencies
# !pip install -r requirements.txt
# !npm install -g localtunnel

# 4. Fix Basicsr (Required for RealESRGAN)
# !grep -rl 'functional_tensor' /home/zeus/miniconda3/envs/cloudspace/lib/python*/site-packages/basicsr/ | xargs sed -i 's/functional_tensor/functional/g' || true

# %%
# 5. Start Server and LocalTunnel
import time

print("\n\n🔥 STARTING NEXUS PRO ON LIGHTNING AI GPU 🔥")
subprocess.Popen(["python", "app.py"])
time.sleep(5)

p = subprocess.Popen(["lt", "--port", str(PORT)], stdout=subprocess.PIPE)
out = p.stdout.readline().decode('utf-8').strip()
url = out.split(" ")[-1]
print(f"\n\n👉 COPY THIS URL INTO YOUR LOCAL APP: {url} 👈")
print("=" * 50 + "\n")

p.wait()
